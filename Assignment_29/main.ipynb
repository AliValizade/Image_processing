# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('input/3.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img.shape
# Out:
# (706, 706, 3)

# %%
r, g, b = cv.split(img)

# %%
b.shape
# Out:
# (706, 706)

# %%
plt.imshow(b, cmap='gray')

# %%
logo = np.zeros((600 , 1000, 3), dtype=np.uint8)
plt.imshow(logo)

# %%
# red
logo[100:200, 100:200] = (246, 83, 20)
# green
logo[100:200, 210:310] = (124, 187, 0)
# blue
logo[210:310, 100:200] = (0, 161, 241)
# yellow
logo[210:310, 210:310] = (255, 187, 0)

# %%
logo = cv.putText(logo, 'Microsoft', (320, 250), cv.FONT_HERSHEY_COMPLEX, 4, (255, 255, 255), 8)

# %%
plt.imshow(logo)
